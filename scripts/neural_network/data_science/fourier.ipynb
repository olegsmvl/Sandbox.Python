# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 1000)
sin_wave = np.sin(x)
square_wave = np.sign(np.sin(x))
sin_wave_3 = np.sin(3*x)/3

result = sin_wave +sin_wave_3

N = 10
fourier_series = np.zeros_like(x)

plt.plot(x, square_wave)
plt.plot(x,sin_wave)
plt.plot(x,sin_wave_3)
plt.plot(x,result)
plt.grid(True)
plt.show()

# %%
t = range(5)
t
# Out:
# range(0, 5)
