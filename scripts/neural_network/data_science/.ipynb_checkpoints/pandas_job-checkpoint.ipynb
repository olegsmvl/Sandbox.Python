# %%
import pandas as pd

# %%
df = pd.read_csv('/home/fly/work/job_data/cpp_all_onsite_belgrade.csv')

# %%
df.shape
# Out:
# (555, 13)

# %%
df.columns
# Out:
# Index(['Title', 'Description', 'Primary Description', 'Detail URL', 'Location',
#        'Skill', 'Insight', 'Job State', 'Poster Id', 'Company Name',
#        'Company Logo', 'Created At', 'Scraped At'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                                    Title  \
# 0              Site Reliability Engineer
# 1     Senior Back End Developer (Hybrid)
# 2  Team Lead - Senior Front End Engineer
#
#                                          Description  \
# 0  About Us At Tenderly, we're not just shaping t...
# 1  KMS Lighthouse is a global software (SaaS) com...
# 2  We’re looking for a Senior Front End Developer...
#
#                                  Primary Description  \
# 0              Tenderly · Belgrade, Serbia (On-site)
# 1    KMS Lighthouse · Novi Beograd, Serbia (On-site)
# 2  Ottometric · Novi Sad, Vojvodina, Serbia (Hybrid)
#
#                                        Detail URL  \
# 0  https://www.linkedin.com/jobs/view/3311916353/
# 1  https://www.linkedin.com/jobs/view/3623807169/
# 2  https://www.linkedin.com/jobs/view/3624937209/
#
#                       Location  \
# 0             Belgrade, Serbia
# 1         Novi Beograd, Serbia
# 2  Novi Sad, Vojvodina, Serbia
#
#                                                Skill  \
# 0  Skills: Software Development, Site Reliability...
# 1  Skills: Back-End Web Development, Software Dev...
# 2    Skills: Software Development, Redux.js, +8 more
#
#                                    Insight Job State    Poster Id  \
# 0                         51-200 employees    LISTED  405051477.0
# 1  51-200 employees · Information Services    LISTED          NaN
# 2                                      NaN    LISTED          NaN
#
#      Company Name                                       Company Logo  \
# 0        Tenderly  https://media.licdn.com/dms/image/D4D0BAQG94R_...
# 1  KMS Lighthouse  https://media.licdn.com/dms/image/C4E0BAQHDbt9...
# 2             NaN                                                NaN
#
#                  Created At                Scraped At
# 0  2022-10-18T11:05:54.000Z  2024-07-21T21:25:52.585Z
# 1  2023-06-05T20:16:29.000Z  2024-07-21T21:26:05.341Z
# 2  2023-06-02T00:13:47.000Z  2024-07-21T21:26:31.096Z

# %%
descriptions = df['Skill']
descriptions.head(20)
# Out:
# 0     Skills: Software Development, Site Reliability...
# 1     Skills: Back-End Web Development, Software Dev...
# 2       Skills: Software Development, Redux.js, +8 more
# 3     Skills: Back-End Web Development, Android Deve...
# 4     Skills: Computer Engineering, Infotainment, +5...
# 5     Skills: Integration Development, Dell Boomi, +...
# 6     Skills: Statistical Programming, CDISC Standar...
# 7     Skills: Statistical Programming, Study Data Ta...
# 8                            Skills: Java, C++, +8 more
# 9                            Skills: Java, C++, +8 more
# 10                           Skills: Java, C++, +8 more
# 11    Skills: Software Development, Project Plans, +...
# 12    Skills: Statistical Programming, Study Data Ta...
# 13    Skills: Python (Programming Language), Communi...
# 14    Skills: Python (Programming Language), Communi...
# 15    Skills: Back-End Web Development, Software Dev...
# 16    Skills: Software Development, Project Plans, +...
# 17                           Skills: Java, C++, +8 more
# 18      Skills: Java, Back-End Web Development, +6 more
# 19                  Skills: .NET Framework, C#, +8 more
# Name: Skill, dtype: object

# %%
df['Company Name'].value_counts().head(50)
# Out:
# Company Name
# Qinshift                               41
# FIS                                    18
# Merkle                                 14
# myGwork - LGBTQ+ Business Community    14
# Wargaming                              14
# Orion Innovation                       13
# Synechron                              13
# Rivian                                 12
# Holycode                               12
# Databricks                             10
# Clarivate                              10
# Paycor                                 10
# Oil and Gas Job Search Ltd              9
# Engineering Software Lab Serbia         9
# NCR Voyix                               8
# Luxoft                                  8
# Schneider Electric                      8
# Grid Dynamics                           7
# Acronis                                 7
# Gorgias                                 7
# NCR Atleos                              7
# Friendly HR                             7
# InterVenture                            6
# BlackRock                               6
# LotusFlare                              6
# Worldwide Clinical Trials               6
# Netconomy                               6
# Acumatica                               5
# Sportserve                              5
# Microsoft                               5
# Team Sava                               5
# SMG Swiss Marketplace Group Serbia      4
# EV.Careers                              4
# Scopeworker                             4
# Zühlke Group                            4
# Cisco                                   4
# Incode                                  4
# Yassir                                  4
# symphony.is                             4
# Top Remote Talent                       4
# Crayon                                  3
# Merkle DACH                             3
# Citrus Systems                          3
# Portfolio BI                            3
# Ananas E-commerce                       3
# Schneider Electric Hub                  3
# ASEE                                    3
# Hyperoptic                              3
# BVP                                     3
# STRABAG                                 3
# Name: count, dtype: int64

# %%
df[df['Company Name'] == 'Qinshift' & df['Title'].str.contains('C\+\+', case=False, regex=True, na=False)].head(16)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:311, in na_logical_op(x, y, op)
#     302 try:
#     303     # For exposition, write:
#     304     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     309     # Then Cases where this goes through without raising include:
#     310     #  (xint or xbool) and (yint or bool)
# --> 311     result = op(x, y)
#     312 except TypeError:
#
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:325, in na_logical_op(x, y, op)
#     324 try:
# --> 325     result = libops.scalar_binop(x, y, op)
#     326 except (
#     327     TypeError,
#     328     ValueError,
#    (...)
#     331     NotImplementedError,
#     332 ) as err:
#
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/_libs/ops.pyx:180, in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'bool'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df[df['Company Name'] == 'Qinshift' & df['Title'].str.contains('C/+/+', case=False, regex=True, na=False)].head(16)
#
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/arraylike.py:74, in OpsMixin.__rand__(self, other)
#      72 @unpack_zerodim_and_defer("__rand__")
#      73 def __rand__(self, other):
# ---> 74     return self._logical_method(other, roperator.rand_)
#
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/series.py:6107, in Series._logical_method(self, other, op)
#    6104 lvalues = self._values
#    6105 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6107 res_values = ops.logical_op(lvalues, rvalues, op)
#    6108 return self._construct_result(res_values, name=res_name)
#
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:401, in logical_op(left, right, op)
#     397 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     398 #   integer dtypes.  Otherwise these are boolean ops
#     399 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 401 res_values = na_logical_op(lvalues, rvalues, op)
#     402 # error: Cannot call function of unknown type
#     403 res_values = filler(res_values)  # type: ignore[operator]
#
# File ~/code/Sandbox.Python/scripts/neural_network/data_science/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:334, in na_logical_op(x, y, op)
#     326         except (
#     327             TypeError,
#     328             ValueError,
#    (...)
#     331             NotImplementedError,
#     332         ) as err:
#     333             typ = type(y).__name__
# --> 334             raise TypeError(
#     335                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     336                 f"and scalar of type [{typ}]"
#     337             ) from err
#     339 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [bool] array and scalar of type [bool]

# %%
df['Location'].value_counts().head(10)
# Out:
# Location
# Belgrade, Serbia                        389
# Novi Sad, Vojvodina, Serbia              51
# Serbia                                   39
# Novi Beograd, Serbia                     23
# Kragujevac, Centralna Srbija, Serbia     11
# Stari Grad, Serbia                       11
# Novi Sad Metropolitan Area                7
# Niš, Centralna Srbija, Serbia             6
# Belgrade Metropolitan Area                5
# Srem District, Vojvodina, Serbia          3
# Name: count, dtype: int64

# %%
df[df['Location'] == 'Poland'].head(3)
# Out:
# Empty DataFrame
# Columns: [Title, Description, Primary Description, Detail URL, Location, Skill, Insight, Job State, Poster Id, Company Name, Company Logo, Created At, Scraped At]
# Index: []

# %%
df[df['Title'] == 'Robotics Software Engineer']
# Out:
# Empty DataFrame
# Columns: [Title, Description, Primary Description, Detail URL, Location, Skill, Insight, Job State, Poster Id, Company Name, Company Logo, Created At, Scraped At]
# Index: []

# %%
ser =  df['Title'].str.contains('developer|engineer|robotics', case=False, regex=True)
filtered = df[ser]

# %%
ser_skill = df['Skill'].str.contains('robotics', case=False, regex=True, na=False).dropna()
df[ser_skill].iloc[40:50]
# Out:
# Empty DataFrame
# Columns: [Title, Description, Primary Description, Detail URL, Location, Skill, Insight, Job State, Poster Id, Company Name, Company Logo, Created At, Scraped At]
# Index: []

# %%
string_list = df['Skill'].dropna().tolist()
def remove_words(text):
    text = text.replace('Skills: ', "")
    text = text.strip()
    return text

# Применение функции к каждому элементу списка
modified_list = [remove_words(text) for text in string_list]

# %%
values_combined = ','.join(map(str, modified_list))
values_list = values_combined.split(',')
values_list = [s.split() for  s in values_list]
new_series = pd.Series(values_list, name='Combined_skills')
new_series
# Out:
# 0                                 [Software, Development]
# 1                        [Site, Reliability, Engineering]
# 2                                              [+8, more]
# 3                            [Back-End, Web, Development]
# 4                                 [Software, Development]
#                               ...
# 1616                                           [+4, more]
# 1617                                    [.NET, Framework]
# 1618                [Object-Oriented, Programming, (OOP)]
# 1619                                           [+8, more]
# 1620    [3, of, 4, skills, match, your, profile, -, yo...
# Name: Combined_skills, Length: 1621, dtype: object

# %%
counts = new_series.value_counts()
counts
# Out:
# Combined_skills
# [+8, more]                                                                 445
# [Software, Development]                                                     84
# [Back-End, Web, Development]                                                68
# [Java]                                                                      67
# [Python, (Programming, Language)]                                           65
#                                                                           ...
# [Procedural, Programming]                                                    1
# [npm]                                                                        1
# [Mobile, Applications]                                                       1
# [Server, Management]                                                         1
# [3, of, 4, skills, match, your, profile, -, you, may, be, a, good, fit]      1
# Name: count, Length: 257, dtype: int64

# %%
# Имя файла для сохранения
filename = '/home/fly/temp/value_counts.txt'

# Сохранение результата в файл
with open(filename, 'w') as file:
    file.write(counts.to_string())

print(f"Результат value_counts() сохранен в файл {filename}")
# Out:
# Результат value_counts() сохранен в файл /home/fly/temp/value_counts.txt

# %%
filtered_df = df[df['Skill'].str.contains('python', case=False, na=False)]
filtered_df
# Out:
#                                            Title  \
# 13                          Azure Cloud Engineer
# 14                            AWS Cloud Engineer
# 30                               DevOps Engineer
# 42   Senior Embedded Software Architect (Hybrid)
# 49     Senior Full-Stack Engineer ReactJS/NodeJS
# ..                                           ...
# 522            Embedded Python Engineer (Hybrid)
# 528                 Data Engineer - Planted Team
# 532               Business Intelligence Engineer
# 533                    Data Engineer - Data Lake
# 547                        C++ Software Engineer
#
#                                            Description  \
# 13   \nCompany Description\n\nAs a part of Devoteam...
# 14   \nCompany Description\n\nAs a part of Devoteam...
# 30   Requirements\n\nJob Requirements\n\nBachelor’s...
# 42   Orion Innovation is a premier, award-winning, ...
# 49   Gorgias empowers ecommerce brands to grow thro...
# ..                                                 ...
# 522  Orion Innovation is a premier, award-winning, ...
# 528  We at Holycode are currently looking for a Dat...
# 532  About Trace One\nTrace One is a global leader ...
# 533  Company DescriptionZenith System Solutions is ...
# 547  Who We Are:\n\nWe seeking for an experienced a...
#
#                                    Primary Description  \
# 13     Devoteam · Novi Sad, Vojvodina, Serbia (Hybrid)
# 14     Devoteam · Novi Sad, Vojvodina, Serbia (Hybrid)
# 30             Braintrust · Belgrade, Serbia (On-site)
# 42                  Orion Innovation · Serbia (Hybrid)
# 49                Gorgias · Belgrade, Serbia (On-site)
# ..                                                 ...
# 522       Orion Innovation · Belgrade, Serbia (Hybrid)
# 528              Holycode · Belgrade, Serbia (On-site)
# 532              Trace One · Belgrade, Serbia (Hybrid)
# 533  Zenith System Solutions · Belgrade, Serbia (Hy...
# 547                  Cisco · Belgrade, Serbia (Hybrid)
#
#                                          Detail URL  \
# 13   https://www.linkedin.com/jobs/view/3737648892/
# 14   https://www.linkedin.com/jobs/view/3737654153/
# 30   https://www.linkedin.com/jobs/view/3810299278/
# 42   https://www.linkedin.com/jobs/view/3846585692/
# 49   https://www.linkedin.com/jobs/view/3860719722/
# ..                                              ...
# 522  https://www.linkedin.com/jobs/view/3978003961/
# 528  https://www.linkedin.com/jobs/view/3978537618/
# 532  https://www.linkedin.com/jobs/view/3978702505/
# 533  https://www.linkedin.com/jobs/view/3978925193/
# 547  https://www.linkedin.com/jobs/view/3979987941/
#
#                         Location  \
# 13   Novi Sad, Vojvodina, Serbia
# 14   Novi Sad, Vojvodina, Serbia
# 30              Belgrade, Serbia
# 42                        Serbia
# 49              Belgrade, Serbia
# ..                           ...
# 522             Belgrade, Serbia
# 528             Belgrade, Serbia
# 532             Belgrade, Serbia
# 533             Belgrade, Serbia
# 547             Belgrade, Serbia
#
#                                                  Skill  \
# 13   Skills: Python (Programming Language), Communi...
# 14   Skills: Python (Programming Language), Communi...
# 30   Skills: Software Development, Python (Programm...
# 42   Skills: C (Programming Language), Python (Prog...
# 49   Skills: Python (Programming Language), Technic...
# ..                                                 ...
# 522  Skills: Python (Programming Language), C (Prog...
# 528  Skills: Python (Programming Language), Code Re...
# 532     Skills: Python (Programming Language), Tableau
# 533  Skills: Linux, Python (Programming Language), ...
# 547  Skills: Software Development, Python (Programm...
#
#                                                Insight Job State  \
# 13   10,001+ employees · Business Consulting and Se...    LISTED
# 14   10,001+ employees · Business Consulting and Se...    LISTED
# 30   11-50 employees · Technology, Information and ...    LISTED
# 42   5,001-10,000 employees · IT Services and IT Co...    LISTED
# 49            201-500 employees · Software Development    LISTED
# ..                                                 ...       ...
# 522  5,001-10,000 employees · IT Services and IT Co...    LISTED
# 528           201-500 employees · Software Development    LISTED
# 532         501-1,000 employees · Software Development    LISTED
# 533                                  201-500 employees    LISTED
# 547           10,001+ employees · Software Development    LISTED
#
#         Poster Id             Company Name  \
# 13   3.703449e+08                 Devoteam
# 14   3.703449e+08                 Devoteam
# 30   2.661976e+08               Braintrust
# 42   4.299592e+07         Orion Innovation
# 49            NaN                  Gorgias
# ..            ...                      ...
# 522  4.299592e+07         Orion Innovation
# 528           NaN                 Holycode
# 532  4.041628e+08                Trace One
# 533  1.004573e+09  Zenith System Solutions
# 547  6.443521e+08                    Cisco
#
#                                           Company Logo  \
# 13   https://media.licdn.com/dms/image/C560BAQEloqE...
# 14   https://media.licdn.com/dms/image/C560BAQEloqE...
# 30   https://media.licdn.com/dms/image/D560BAQElwT1...
# 42   https://media.licdn.com/dms/image/D560BAQG30ho...
# 49   https://media.licdn.com/dms/image/D560BAQGwfHf...
# ..                                                 ...
# 522  https://media.licdn.com/dms/image/D560BAQG30ho...
# 528  https://media.licdn.com/dms/image/D4D0BAQE133Q...
# 532  https://media.licdn.com/dms/image/C4D0BAQE8llR...
# 533  https://media.licdn.com/dms/image/C560BAQEyT0g...
# 547  https://media.licdn.com/dms/image/D560BAQHS78g...
#
#                    Created At                Scraped At
# 13   2023-10-13T20:17:04.000Z  2024-07-21T21:23:54.082Z
# 14   2023-10-13T20:17:05.000Z  2024-07-21T21:23:41.165Z
# 30   2024-01-19T14:04:32.000Z  2024-07-21T21:24:33.171Z
# 42   2024-03-05T15:38:40.000Z  2024-07-21T21:22:50.172Z
# 49   2024-03-17T04:29:28.000Z  2024-07-21T21:26:57.237Z
# ..                        ...                       ...
# 522  2024-07-16T21:37:04.000Z  2024-07-21T21:22:50.172Z
# 528  2024-07-17T17:41:43.000Z  2024-07-21T21:24:59.122Z
# 532  2024-07-19T09:33:09.000Z  2024-07-21T21:26:05.342Z
# 533  2024-07-20T17:07:47.000Z  2024-07-21T21:25:52.587Z
# 547  2024-07-19T10:54:50.000Z  2024-07-21T21:22:50.172Z
#
# [65 rows x 13 columns]
